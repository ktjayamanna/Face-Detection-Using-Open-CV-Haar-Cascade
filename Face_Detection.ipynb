# %% [markdown]
# <a href="https://colab.research.google.com/github/ktjayamanna/Face-Detection-Using-Open-CV-Haar-Cascade/blob/master/Face_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import cv2
import scipy as sp
import urllib.request
import imutils
from PIL import Image

# %%
#Get the URL for the Haar Cascade
HaarCascadeURL = 'https://github.com/opencv/opencv/tree/master/data/haarcascades'

#Get the Name of the Haar Cascade Version
HaarName = 'haarcascade_frontalface_default.xml'

urllib.request.urlretrieve(HaarCascadeURL,HaarName)

#Read the Subject Image
TrumpImage = cv2.imread('trump.jpg')

# %%
# Initialize the Classifier
detector = cv2.CascadeClassifier(cv2.data.haarcascades +'haarcascade_frontalface_default.xml')
#Make List of Faces in the Image
FaceList = detector.detectMultiScale(TrumpImage)

# %%
for face in FaceList:
    (x,y,w,h) = face
    cv2.rectangle(TrumpImage,(x,y),(x+w,y+h),(0,255,0),3)
plt.imshow(TrumpImage)

# %%
#Cropping the Faces
for face in FaceList:
    (x,y,w,h) = face
    temp = TrumpImage[y:y+h,x:x+w]
    # Resize to 100 x 100 pixels
    FaceResized = cv2.resize(temp,(100,100))
    plt.figure();
    plt.imshow(FaceResized)
